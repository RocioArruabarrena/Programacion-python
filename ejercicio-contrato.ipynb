# %% [markdown]
# ## Ejercicio Python Contrato
#
# ### Complete el codigo necesario para poder imprimir todos los contratos

# %%
#Arruabarrena Rocio 
# Link a la pagina para la generar los datos "https://www.mockaroo.com/"
from pprint import pprint
misdatos = [{
    "nombre_locador": "Rozina",
    "apellido_locador": "Grigorushkin",
    "nombre_inquilino": "Darelle",
    "apellido_iniquilino": "Menlove",
    "dni_locador": 54192524,
    "dni_inquilino": 35905765,
    "domicilio_locador":"70913 Merrick Street",
    "domicilio_locatario":"9 Kedzie Parkway",
    "local_domicilio":"64 Harper Plaza",
    "años_de_alquiler":1,
    "inicio_de_alquiler":"7/23/2025",
    "final_de_alquiler":"9/20/2026",
    "cbu_locatario":"5048376056771956",
    "monto_mesual":"$62503.20",
    "actividad_del_local":"Movies",
    "cant_meses_garantia":1,
    "localidad_tribunales":"Xianhe",
    "lugar_de_firma":"Cangkringan",
    "monto_garantia": "$65381.16",
    "mes_de_firma": "Agosto",
    "dia_de_firma": 1,
    "año_de_firma": 2024    
}, {
    "nombre_locador": "Alic",
    "apellido_locador": "Wallworke",
    "nombre_inquilino": "Clarisse",
    "apellido_iniquilino": "Faucett",
    "dni_locador": 23673028,
    "dni_inquilino": 31424910,
    "domicilio_locador":"5 Springs Junction",
    "domicilio_locatario":"035 Vahlen Point",
    "local_domicilio":"4312 Forest Point",
    "años_de_alquiler":2,
    "inicio_de_alquiler":"7/1/2025",
    "final_de_alquiler":"5/7/2026",
    "cbu_locatario":"5108751889695647",
    "monto_mesual":"$53844.42",
    "actividad_del_local":"Movies",
    "cant_meses_garantia":2,
    "localidad_tribunales":"Mato Cheirinhos",
    "lugar_de_firma":"Lyon",
    "monto_garantia": "$94357.58",
    "mes_de_firma": "Septiembre",
    "dia_de_firma": 2,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Maisey",
    "apellido_locador": "Bramelt",
    "nombre_inquilino": "Denny",
    "apellido_iniquilino": "Zanotti",
    "dni_locador": 46161009,
    "dni_inquilino": 41238885,
    "domicilio_locador":"3271 Chinook Trail",
    "domicilio_locatario":"40 Brickson Park Center",
    "local_domicilio":"4 Lunder Avenue",
    "años_de_alquiler":3,
    "inicio_de_alquiler":"1/3/2025",
    "final_de_alquiler":"4/2/2026",
    "cbu_locatario":"5048377830199480",
    "monto_mesual":"$15016.11",
    "actividad_del_local":"Outdoors",
    "cant_meses_garantia":3,
    "localidad_tribunales":"Znamenskoye",
    "lugar_de_firma":"Biggar",
    "monto_garantia": "$22110.53",
    "mes_de_firma": "Octubre",
    "dia_de_firma": 3,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Lynda",
    "apellido_locador": "Book",
    "nombre_inquilino": "Elvina",
    "apellido_iniquilino": "Pllu",
    "dni_locador": 23719559,
    "dni_inquilino": 39994919,
    "domicilio_locador":"007 Washington Trail",
    "domicilio_locatario":"427 Tennessee Court",
    "local_domicilio":"223 Delaware Road",
    "años_de_alquiler":4,
    "inicio_de_alquiler":"4/16/2025",
    "final_de_alquiler":"11/29/2025",
    "cbu_locatario":"5048371375665658",
    "monto_mesual":"$11236.09",
    "actividad_del_local":"Automotive",
    "cant_meses_garantia":4,
    "localidad_tribunales":"Kremenki",
    "lugar_de_firma":"Ribeirópolis",
    "monto_garantia": "$29748.96",
    "mes_de_firma": "Noviembre",
    "dia_de_firma": 4,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Brodie",
    "apellido_locador": "Timothy",
    "nombre_inquilino": "Dani",
    "apellido_iniquilino": "Greenset",
    "dni_locador": 29603958,
    "dni_inquilino": 28491385,
    "domicilio_locador":"27171 Esch Crossing",
    "domicilio_locatario":"361 Summerview Drive",
    "local_domicilio":"2 Mifflin Circle",
    "años_de_alquiler":5,
    "inicio_de_alquiler":"4/5/2025",
    "final_de_alquiler":"8/18/2026",
    "cbu_locatario":"5108755091821669",
    "monto_mesual":"$65469.64",
    "actividad_del_local":"Grocery",
    "cant_meses_garantia":5,
    "localidad_tribunales":"Baqiao",
    "lugar_de_firma":"Zhoutian",
    "monto_garantia": "$66387.58",
    "mes_de_firma": "Diciembre",
    "dia_de_firma": 5,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Orren",
    "apellido_locador": "Zavittieri",
    "nombre_inquilino": "Delora",
    "apellido_iniquilino": "Guilloneau",
    "dni_locador": 32322572,
    "dni_inquilino": 22259409,
    "domicilio_locador":"527 8th Parkway",
    "domicilio_locatario":"78 Bobwhite Court",
    "local_domicilio":"4 Granby Court",
    "años_de_alquiler":6,
    "inicio_de_alquiler":"4/5/2024",
    "final_de_alquiler":"5/1/2024",
    "cbu_locatario":"5048373836694582",
    "monto_mesual":"$22294.19",
    "actividad_del_local":"Beauty",
    "cant_meses_garantia":6,
    "localidad_tribunales":"Orivesi",
    "lugar_de_firma":"Wahang Dua",
    "monto_garantia": "$47872.24",
    "mes_de_firma": "Enero",
    "dia_de_firma": 6,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Blanche",
    "apellido_locador": "Lyford",
    "nombre_inquilino": "Kata",
    "apellido_iniquilino": "Ilyuchyov",
    "dni_locador": 21345958,
    "dni_inquilino": 37768529,
    "domicilio_locador":"34 Duke Parkway",
    "domicilio_locatario":"98095 Duke Hill",
    "local_domicilio":"9539 Oak Park",
    "años_de_alquiler":7,
    "inicio_de_alquiler":"2/17/2024",
    "final_de_alquiler":"11/29/2026",
    "cbu_locatario":"5108755777452623",
    "monto_mesual":"$31833.09",
    "actividad_del_local":"Automotive",
    "cant_meses_garantia":7,
    "localidad_tribunales":"Gävle",
    "lugar_de_firma":"Baiyangwan",
    "monto_garantia": "$45820.39",
    "mes_de_firma": "Febrero",
    "dia_de_firma": 7,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Judah",
    "apellido_locador": "Bowland",
    "nombre_inquilino": "Lacy",
    "apellido_iniquilino": "Nanni",
    "dni_locador": 37728261,
    "dni_inquilino": 16095354,
    "domicilio_locador":"0206 Maple Court",
    "domicilio_locatario":"16375 Fair Oaks Point",
    "local_domicilio":"266 Harbort Park",
    "años_de_alquiler":8,
    "inicio_de_alquiler":"12/29/2024",
    "final_de_alquiler":"12/29/2025",
    "cbu_locatario":"5108758023868774",
    "monto_mesual":"$82380.06",
    "actividad_del_local":"Beauty",
    "cant_meses_garantia":8,
    "localidad_tribunales":"Gharavŭtí",
    "lugar_de_firma":"Woloara",
    "monto_garantia": "$45756.10",
    "mes_de_firma": "Marzo",
    "dia_de_firma": 8,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Garner",
    "apellido_locador": "MacConnulty",
    "nombre_inquilino": "Carmela",
    "apellido_iniquilino": "Sevitt",
    "dni_locador": 43570352,
    "dni_inquilino": 49980448,
    "domicilio_locador":"2 Monica Pass",
    "domicilio_locatario":"84129 Kennedy Center",
    "local_domicilio":"22 Hazelcrest Park",
    "años_de_alquiler":9,
    "inicio_de_alquiler":"11/21/2024",
    "final_de_alquiler":"4/3/2026",
    "cbu_locatario":"5048379432006063",
    "monto_mesual":"$67701.28",
    "actividad_del_local":"Health",
    "cant_meses_garantia":9,
    "localidad_tribunales":"Táriba",
    "lugar_de_firma":"Kruševica",
    "monto_garantia": "$50082.64",
    "mes_de_firma": "Abril",
    "dia_de_firma": 9,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Innis",
    "apellido_locador": "Prandi",
    "nombre_inquilino": "Roseline",
    "apellido_iniquilino": "Corzor",
    "dni_locador": 39265115,
    "dni_inquilino": 30868693,
    "domicilio_locador":"33 Jenna Terrace",
    "domicilio_locatario":"01578 Montana Road",
    "local_domicilio":"92805 Petterle Center",
    "años_de_alquiler":10,
    "inicio_de_alquiler":"11/18/2024",
    "final_de_alquiler":"5/31/2025",
    "cbu_locatario":"5048372434784027",
    "monto_mesual":"$39104.99",
    "actividad_del_local":"Kids",
    "cant_meses_garantia":10,
    "localidad_tribunales":"Shuanghekou",
    "lugar_de_firma":"Pochuta",
    "monto_garantia": "$76867.15",
    "mes_de_firma": "Mayo",
    "dia_de_firma": 10,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Yetty",
    "apellido_locador": "Adacot",
    "nombre_inquilino": "Rici",
    "apellido_iniquilino": "Pincked",
    "dni_locador": 26563745,
    "dni_inquilino": 24303563,
     "domicilio_locador":"2 Merchant Crossing",
    "domicilio_locatario":"2001 Bellgrove Trail",
    "local_domicilio":"5 Beilfuss Plaza",
    "años_de_alquiler":11,
    "inicio_de_alquiler":"6/30/2025",
    "final_de_alquiler":"10/4/2023",
    "cbu_locatario":"5108755717064066",
    "monto_mesual":"$38651.63",
    "actividad_del_local":"Shoes",
    "cant_meses_garantia":11,
    "localidad_tribunales":"London",
    "lugar_de_firma":"Belén Gualcho",
    "monto_garantia": "$88964.01",
    "mes_de_firma": "Junio",
    "dia_de_firma": 11,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Nari",
    "apellido_locador": "Raubenheim",
    "nombre_inquilino": "Othilie",
    "apellido_iniquilino": "Lefort",
    "dni_locador": 15434318,
    "dni_inquilino": 32880233,
    "domicilio_locador":"6808 Buena Vista Road",
    "domicilio_locatario":"8563 Tomscot Road",
    "local_domicilio":"7616 Crest Line Drive",
    "años_de_alquiler":12,
    "inicio_de_alquiler":"10/18/2024",
    "final_de_alquiler":"7/22/2027",
    "cbu_locatario":"5048372474659659",
    "monto_mesual":"$86182.82",
    "actividad_del_local":"Tools",
    "cant_meses_garantia":12,
    "localidad_tribunales":"Seaton",
    "lugar_de_firma":"Maychew",
    "monto_garantia": "$74590.12",
    "mes_de_firma": "Julio",
    "dia_de_firma": 12,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Quinta",
    "apellido_locador": "Zucker",
    "nombre_inquilino": "Heall",
    "apellido_iniquilino": "Klimmek",
    "dni_locador": 35702039,
    "dni_inquilino": 36639814,
    "domicilio_locador":"47 Lotheville Lane",
    "domicilio_locatario":"808 Kenwood Crossing",
    "local_domicilio":"4154 Pine View Pass",
    "años_de_alquiler":13,
    "inicio_de_alquiler":"1/7/2024",
    "final_de_alquiler":"11/8/2024",
    "cbu_locatario":"5048376308717054",
    "monto_mesual":"$85416.46",
    "actividad_del_local":"Home",
    "cant_meses_garantia":13,
    "localidad_tribunales":"Kuttu",
    "lugar_de_firma":"Shuyuan",
    "monto_garantia": "$12519.14",
    "mes_de_firma": "Agosto",
    "dia_de_firma": 13,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Leela",
    "apellido_locador": "Swaisland",
    "nombre_inquilino": "Aurlie",
    "apellido_iniquilino": "Week",
    "dni_locador": 40773854,
    "dni_inquilino": 47171253,
    "domicilio_locador":"1040 Scott Alley",
    "domicilio_locatario":"88 Becker Hill",
    "local_domicilio":"64 Service Way",
    "años_de_alquiler":14,
    "inicio_de_alquiler":"2/28/2024",
    "final_de_alquiler":"4/16/2025",
    "cbu_locatario":"5108751333488623",
    "monto_mesual":"$51398.92",
    "actividad_del_local":"Electronics",
    "cant_meses_garantia":14,
    "localidad_tribunales":"Handa",
    "lugar_de_firma":"Xinpo",
    "monto_garantia": "$13114.75",
    "mes_de_firma": "Septiembre",
    "dia_de_firma": 14,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Spence",
    "apellido_locador": "Adiscot",
    "nombre_inquilino": "Stephanus",
    "apellido_iniquilino": "Thorowgood",
    "dni_locador": 43789602,
    "dni_inquilino": 29189903,
    "domicilio_locador":"0272 Golf Circle",
    "domicilio_locatario":"3796 Holmberg Plaza",
    "local_domicilio":"82794 Miller Junction",
    "años_de_alquiler":15,
    "inicio_de_alquiler":"3/25/2024",
    "final_de_alquiler":"6/14/2026",
    "cbu_locatario":"5108752745151213",
    "monto_mesual":"$82250.04",
    "actividad_del_local":"Beauty",
    "cant_meses_garantia":15,
    "localidad_tribunales":"Yangjiao",
    "lugar_de_firma":"Mönhbulag",
    "monto_garantia": "$93799.43",
    "mes_de_firma": "Octubre",
    "dia_de_firma": 15,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Zacharia",
    "apellido_locador": "Roz",
    "nombre_inquilino": "Terry",
    "apellido_iniquilino": "Hew",
    "dni_locador": 38324664,
    "dni_inquilino": 22056403,
    "domicilio_locador":"04445 Schlimgen Terrace",
    "domicilio_locatario":"8476 Helena Terrace",
    "local_domicilio":"516 Center Court",
    "años_de_alquiler":16,
    "inicio_de_alquiler":"12/26/2024",
    "final_de_alquiler":"2/8/2024",
    "cbu_locatario":"5108753226837957",
    "monto_mesual":"$24435.92",
    "actividad_del_local":"Music",
    "cant_meses_garantia":16,
    "localidad_tribunales":"Tīrān",
    "lugar_de_firma":"Fangyan",
    "monto_garantia": "$67701.63",
    "mes_de_firma": "Noviembre",
    "dia_de_firma": 16,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Brucie",
    "apellido_locador": "Vinas",
    "nombre_inquilino": "Owen",
    "apellido_iniquilino": "Bolsover",
    "dni_locador": 33606991,
    "dni_inquilino": 37145851,
    "domicilio_locador":"67564 Roxbury Avenue",
    "domicilio_locatario":"46 Loeprich Terrace",
    "local_domicilio":"59 Weeping Birch Center",
    "años_de_alquiler":17,
    "inicio_de_alquiler":"12/9/2023",
    "final_de_alquiler":"1/14/2027",
    "cbu_locatario":"5048370309271849",
    "monto_mesual":"$38561.33",
    "actividad_del_local":"Health",
    "cant_meses_garantia":17,
    "localidad_tribunales":"Candijay",
    "lugar_de_firma":"Riga",
    "monto_garantia": "$47724.34",
    "mes_de_firma": "Diciembre",
    "dia_de_firma": 17,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Garth",
    "apellido_locador": "Dumbreck",
    "nombre_inquilino": "Kat",
    "apellido_iniquilino": "Harston",
    "dni_locador": 27997545,
    "dni_inquilino": 38861200,
    "domicilio_locador":"3661 Paget Terrace",
    "domicilio_locatario":"6635 Schlimgen Way",
    "local_domicilio":"803 Farragut Crossing",
    "años_de_alquiler":18,
    "inicio_de_alquiler":"12/4/2024",
    "final_de_alquiler":"12/16/2024",
    "cbu_locatario":"5108753363438668",
    "monto_mesual":"$56053.96",
    "actividad_del_local":"Home",
    "cant_meses_garantia":18,
    "localidad_tribunales":"Tomobe",
    "lugar_de_firma":"Setanggor",
    "monto_garantia": "$17721.03",
    "mes_de_firma": "Enero",
    "dia_de_firma": 18,
    "año_de_firma": 2024
}, {
    "nombre_locador": "Karla",
    "apellido_locador": "Yeardley",
    "nombre_inquilino": "Stacia",
    "apellido_iniquilino": "Boyles",
    "dni_locador": 48624820,
    "dni_inquilino": 44918384,
    "domicilio_locador":"6 Aberg Pass",
    "domicilio_locatario":"55 Jay Way",
    "local_domicilio":"0 Victoria Plaza",
    "años_de_alquiler":19,
    "inicio_de_alquiler":"10/18/2024",
    "final_de_alquiler":"9/12/2025",
    "cbu_locatario":"5048373214801072",
    "monto_mesual":"$73759.53",
    "actividad_del_local":"Books",
    "cant_meses_garantia":19,
    "localidad_tribunales":"Gucheng",
    "lugar_de_firma":"Sacramento",
    "monto_garantia": "$64275.26",
    "mes_de_firma": "Febrero",
    "dia_de_firma": 19,
    "año_de_firma": 2024
    
}, {
    "nombre_locador": "Marylynne",
    "apellido_locador": "McFater",
    "nombre_inquilino": "Terrance",
    "apellido_iniquilino": "Davitashvili",
    "dni_locador": 34198870,
    "dni_inquilino": 32396619,
     "domicilio_locador":"0136 Merrick Parkway",
    "domicilio_locatario":"299 Sauthoff Court",
    "local_domicilio":"166 Hoard Circle",
    "años_de_alquiler":20,
    "inicio_de_alquiler":"11/19/2024",
    "final_de_alquiler":"9/22/2025",
    "cbu_locatario":"5108758996235365",
    "monto_mesual":"$46282.19",
    "actividad_del_local":"Games",
    "cant_meses_garantia":20,
    "localidad_tribunales":"Diwopu",
    "lugar_de_firma":"Xiaochi",
    "monto_garantia": "$25921.76",
    "mes_de_firma": "Marzo",
    "dia_de_firma": 20,
    "año_de_firma": 2024
}]

for contrato in misdatos:
    micontrato = f'''
CONTRATO DE LOCACIÓN DE INMUEBLE COMERCIAL

Entre:
{contrato['apellido_locador']}, con DNI {contrato['dni_locador']}, domiciliado en {contrato['domicilio_locador']}, en adelante "EL LOCADOR", por una parte,
Y por la otra,
{contrato['apellido_iniquilino']}, con DNI {contrato['dni_inquilino']}, domiciliado en {contrato['domicilio_locatario']}, en adelante "EL LOCATARIO",
Se conviene en celebrar el presente Contrato de Locación, que se regirá por las siguientes cláusulas:

PRIMERA: OBJETO
EL LOCADOR concede en locación a EL LOCATARIO el inmueble ubicado en {contrato['local_domicilio']}, que será destinado exclusivamente para uso comercial {contrato['actividad_del_local']}.

SEGUNDA: PLAZO
El plazo de la locación será de {contrato['años_de_alquiler']} años, comenzando el {contrato['inicio_de_alquiler']} y finalizando el {contrato['final_de_alquiler']}, conforme a lo establecido en el artículo 1199 del Código Civil y Comercial de la Nación.

TERCERA: CANON LOCATIVO
EL LOCATARIO pagará a EL LOCADOR la suma de ${contrato['monto_mesual']} mensuales, pagaderos por mes adelantado, dentro de los primeros 10 días de cada mes en el domicilio de EL LOCADOR o mediante transferencia bancaria a la cuenta {contrato['cbu_locatario']}.
El monto del canon locativo se ajustará anualmente de acuerdo a lo establecido en el artículo 14 de la Ley 27.551, conforme al Índice para Contratos de Locación (ICL) publicado por el Banco Central de la República Argentina (BCRA).

CUARTA: DESTINO
EL LOCATARIO destinará el inmueble exclusivamente para {contrato['actividad_del_local']}, comprometiéndose a no darle otro uso sin la previa y expresa autorización por escrito de EL LOCADOR.

QUINTA: MANTENIMIENTO Y REPARACIONES
EL LOCATARIO se obliga a mantener el inmueble en perfecto estado de conservación y limpieza, obligándose a efectuar las reparaciones menores que sean necesarias durante el transcurso de la locación. Las reparaciones mayores que afecten la estructura o habitabilidad del inmueble serán a cargo de EL LOCADOR.

SEXTA: SERVICIOS E IMPUESTOS
EL LOCATARIO abonará los servicios de luz, agua, gas y los impuestos que correspondan a la actividad comercial desarrollada en el inmueble, incluyendo las tasas municipales por habilitación comercial y publicidad.

SÉPTIMA: GARANTÍA
Como garantía del cumplimiento del presente contrato, EL LOCATARIO entrega a EL LOCADOR un depósito de garantía de ${contrato['monto_garantia']} equivalente a {contrato['cant_meses_garantia']} meses de alquiler, que será devuelto al finalizar el contrato, una vez que EL LOCADOR verifique que el inmueble se encuentra en el estado en que fue recibido, salvo el desgaste normal por uso.

OCTAVA: RESOLUCIÓN ANTICIPADA
EL LOCATARIO podrá rescindir el presente contrato transcurridos al menos seis (6) meses desde su inicio, notificando a EL LOCADOR con una anticipación no menor a tres (3) meses. En tal caso, deberá abonar una indemnización equivalente a un (1) mes y medio de alquiler si la rescisión ocurre dentro del primer año de contrato, y de un (1) mes si ocurre después.

NOVENA: PROHIBICIÓN DE CESIÓN
EL LOCATARIO no podrá ceder, subarrendar o transferir este contrato sin el previo consentimiento por escrito de EL LOCADOR.

DÉCIMA: JURISDICCIÓN
Para todos los efectos judiciales derivados del presente contrato, las partes se someten a la jurisdicción de los Tribunales Ordinarios de {contrato['localidad_tribunales']}, renunciando a cualquier otro fuero o jurisdicción.

DÉCIMOPRIMERA: FIRMAS
En prueba de conformidad, las partes firman el presente contrato en dos (2) ejemplares de igual tenor y a un solo efecto, en {contrato['lugar_de_firma']}, a los {contrato['dia_de_firma']} días del mes de {contrato['mes_de_firma']} de {contrato['año_de_firma']}.

EL LOCADOR
[Nombre y Firma]

EL LOCATARIO
[Nombre y Firma]

'''
    # pprint(micontrato)
    print(micontrato)
